# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('data_prototype_text.csv')
data = df.drop([0])
def plotpie(label):
	question = data.filter([label])
	question = question.dropna()
	values = question.squeeze().value_counts()
	plt.rcParams["figure.figsize"] = (5,5)
	plt.pie(values, labels = values.index, labeldistance=1.15, textprops=dict(color="w"));
	plt.title(label, bbox={'facecolor':'0.8', 'pad':5})
	plt.show();

# %%
# Should work all the way through once we get rid of the open ended questions
for col in data.columns:
	plotpie(col)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-c047f5b504b5> in <module>()
#       1 for col in data.columns:
# ----> 2         plotpie(col)
#
# <ipython-input-70-581210fafb21> in plotpie(label)
#       8         question = data.filter([label])
#       9         question = question.dropna()
# ---> 10         values = question.squeeze().value_counts()
#      11         plt.rcParams["figure.figsize"] = (Integer(5),Integer(5))
#      12         plt.pie(values, labels = values.index, labeldistance=RealNumber('1.15'), textprops=dict(color="w"));
#
# AttributeError: 'str' object has no attribute 'value_counts'

# %%
# Filter data by the response of one question
filtered_df = df.drop([0,1]).filter(['Q1', 'Q22'])
filtered_df = filtered_df.loc[filtered_df['Q1'] == 'Yes'].sort_values(by=['Q22'])
filtered_df
# Out:
#      Q1      Q22
# 34  Yes     Both
# 16  Yes   Google
# 17  Yes   Google
# 18  Yes   Google
# 20  Yes   Google
# 21  Yes   Google
# 23  Yes   Google
# 24  Yes   Google
# 31  Yes   Google
# 36  Yes   Google
# 2   Yes  Neither
# 19  Yes  Neither
# 22  Yes  Neither
# 25  Yes  Neither
# 30  Yes  Neither

# %%
filtered_df[(df['Q22'] == 'Google')].count()
# Out:
# /ext/sage/sage-9.1/local/lib/python3.7/site-packages/sage/repl/ipython_kernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel.kernelapp import IPKernelApp
# Q1     9
# Q22    9
# dtype: int64
